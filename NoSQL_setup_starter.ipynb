# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies

from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
databases=mongo.list_database_names()
databases
# Out:
# ['admin', 'config', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
establishments=db['establishments']
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
establishments.find_one()
# Out:
# {'_id': ObjectId('664aac83a83bb3abc5d2ba90'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours={
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_flavours)
# Out:
# InsertOneResult(ObjectId('664d694ce94d6eaa563e4479'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
establishments.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('664aacc9e94d6eaa563e4477'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True,
#  'RatingValue': None}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
list(establishments.find({'BusinessType':"Restaurant/Cafe/Canteen"},{'BusinessTypeID':1,'BusinessType':1}))
# len(list(establishments.find({'BusinessType':"Restaurant/Cafe/Canteen"},{'BusinessTypeID':1,'BusinessType':1})))
# Out:
# [{'_id': ObjectId('664aac83a83bb3abc5d2ba90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2ba9b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2ba9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baa3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baa4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bab3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bab9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2babc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bac0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bac1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bac4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bac5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bad5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2badc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bade'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bae4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bae8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bae9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baf1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baf3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baf4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baf5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baf6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bafd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2baff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb05'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb07'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb09'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb10'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb1c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb20'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb24'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb29'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb2d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb30'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb32'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb36'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb37'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb39'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb3d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb43'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb44'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb56'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb57'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb59'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb62'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb63'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb69'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb6b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb6d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb75'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb78'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb79'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb7a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb7b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb85'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb86'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac83a83bb3abc5d2bb88'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bb95'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bb96'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bb99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bb9a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bb9c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bba2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bba3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bba6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bba8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbaa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbb1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbb4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbb6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbbc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbc6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbde'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbe2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbe4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bbec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc13'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc15'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc18'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc22'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc27'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc28'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc2a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc2d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc2f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc30'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc31'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc37'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc44'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc48'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc4a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc4b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc4d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc4f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc50'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc52'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc57'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc5b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc5d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc67'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc68'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc69'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc6a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc70'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc7b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc7c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc81'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc8c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc92'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc97'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bc9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bca0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bca1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bca4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcb2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcbd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcc0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcc2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcc6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcc9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bccc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcd4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcd8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcdb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcdc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcde'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcdf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bce3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bce9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bced'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcf0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcf7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcfa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bcfc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd05'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd06'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd07'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd0b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd11'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd12'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd13'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd16'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd1b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd1c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd1e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd1f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd20'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd22'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd23'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd28'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd30'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd32'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd33'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd35'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd37'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd40'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd43'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd45'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd47'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd57'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd64'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd6e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd7b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd80'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd8b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd97'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd98'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd9a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd9d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bd9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bda3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bda6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdb9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdbe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdc1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdc8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdcb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdd3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bddb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bdf1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be02'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be0c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be2a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be2b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be2c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be2d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be3d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be3e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be46'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be4a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be73'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be74'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be76'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be7a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be85'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be87'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be8c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be8e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be95'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be96'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be98'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2be9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2beb2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2beb4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2beb6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2beba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bebb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bec6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bec9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2beca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bed2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bed8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bee1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bee9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2beef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bef2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bef5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bef6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf07'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf10'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf16'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf23'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf2f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf35'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf45'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf4a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf53'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf54'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf62'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf68'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf6a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf6f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac84a83bb3abc5d2bf77'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf79'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf7a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf7b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf7c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf7e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf84'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf85'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf86'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf88'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf8d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf91'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf96'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf98'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf9d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bf9f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfa0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfa1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfa6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfbb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfbc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfbd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfbf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfc0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfc5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfc9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfcb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfcf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfd4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfd5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfd8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfdf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bfef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bff7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2bff8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c009'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c00b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c00d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c00e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c00f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c010'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c011'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c01e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c021'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c022'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c023'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c026'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c02b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c032'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c034'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c039'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c03a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c03b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c03e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c041'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c042'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c048'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c049'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c04a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c04e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c05e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c063'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c06a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c06f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c078'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c079'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c07e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c083'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c085'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c086'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c088'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c08a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c08b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c08e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c08f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c09a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0a0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0b4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0bc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0cf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0d4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0d5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0db'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0fa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c0fd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c108'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac86a83bb3abc5d2c109'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac88a83bb3abc5d2c743'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac88a83bb3abc5d2c744'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac88a83bb3abc5d2c748'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c74d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c74f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c751'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c753'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c757'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c75f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c76a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c76d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c779'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c77a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c784'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c790'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c796'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c799'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7a1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7ab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7af'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7b4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7be'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7c4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7cc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7ef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c7ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c808'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c80a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c817'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c821'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c823'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c824'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c82c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c834'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c849'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c84f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c850'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c853'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c857'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c85a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c85f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c86c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c86d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c870'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c874'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c875'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c87c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c87e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c880'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c884'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c888'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c88b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c88c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c88d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c88e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c891'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c892'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c894'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c89b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c89d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c89e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c89f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8a6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8a9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8b2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8b7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8c1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8c8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ce'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8d6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8db'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8dd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8f8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c8ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c905'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c908'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c90e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c90f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c910'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c912'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c915'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c91c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c91f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c921'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c926'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c928'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c929'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c931'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c934'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c936'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c944'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c947'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c94c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c94f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c957'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c958'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c959'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c95a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c95b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c960'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c961'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c964'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c965'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c96c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('664aac89a83bb3abc5d2c976'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  ...]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName":"Penang Flavours"},{"$set":{"BusinessTypeID":"1"}})
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
establishments.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('664aacc9e94d6eaa563e4477'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True,
#  'RatingValue': None}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
len(list(establishments.find({"LocalAuthorityName":"Dover"})))
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({"LocalAuthorityName":"Dover"})
# Out:
# DeleteResult({'n': 0, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
len(list(establishments.find({"LocalAuthorityName":"Dover"})))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one({"LocalAuthorityName":"Greenwich"})
# Out:
# {'_id': ObjectId('664aac98a83bb3abc5d3277a'),
#  'FHRSID': 1451407,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '14959',
#  'BusinessName': 'Oaks Nursing Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': 'The Oaks 904 Sidcup Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Eltham',
#  'AddressLine4': 'Greenwich',
#  'PostCode': 'SE9 3PW',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-01-12T00:00:00',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.0740289, 'latitude': 51.4320613},
#  'RightToReply': '',
#  'Distance': 4645.598535750726,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'http://api.ratings.food.gov.uk/establishments/1451407'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, 
                           [ {'$set': { "geocode.longitude" : {'$toDouble': "$geocode.longitude"}, 
                                       "geocode.latitude" : {'$toDouble': "$geocode.latitude"}} 
                                       }])
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
establishments.find_one({"LocalAuthorityName":"Greenwich"})
# Out:
# {'_id': ObjectId('664aac98a83bb3abc5d3277a'),
#  'FHRSID': 1451407,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '14959',
#  'BusinessName': 'Oaks Nursing Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': 'The Oaks 904 Sidcup Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Eltham',
#  'AddressLine4': 'Greenwich',
#  'PostCode': 'SE9 3PW',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-01-12T00:00:00',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.0740289, 'latitude': 51.4320613},
#  'RightToReply': '',
#  'Distance': 4645.598535750726,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'http://api.ratings.food.gov.uk/establishments/1451407'}]}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set': { "RatingValue" : {'$toInt': "$RatingValue"}}} ])
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
query = {"RatingValue": {'$gte': 2}}
fields = {"geocode":1, "RatingValue": 1}

# Find the documents and convert cursor to list
results = list(establishments.find(query, fields))

# Print the first two documents
for x in range(2):
    pprint(results[x])
# Out:
# {'RatingValue': 5,
#  '_id': ObjectId('664aac83a83bb3abc5d2ba90'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'RatingValue': 4,
#  '_id': ObjectId('664aac83a83bb3abc5d2ba91'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
